# %% [markdown]
# <div style="border: 4px solid white; padding: 20px; background-color: #2596be; color: white;">
#
# # <b>Explorative Datenanalyse mit Sparky</b>
#
# #### <i>CAS Information Engineering - Modul: Big data - FS 2024</i>
#
# <b> Autoren: </b> Hassler Robin, Tschanz Daniel, Tsiantas Theofanis (Gruppe 10)
#
# </div>

# %% [markdown]
# # Teil 4 - Sparky und Vorhersagen mit Prophet

# %%
zhawaccount = 'tschadan'# TODO set this to your ZHAW-Kürzel

# %%
import sparky
import pyspark
import pandas as pd
#import slash
import pyspark.sql
sc = sparky.connect(f"sparknotebook-{zhawaccount}", 2)
spark = pyspark.sql.SparkSession.builder.getOrCreate()
# Out:
# ~~~ Sparky module loaded ~~~
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/07/01 06:24:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Attached to Sparky cluster context from jupyter-secondary as sparknotebook-tschadan.
# Requested 2 cores; real number might be less.

# %%
# Bibliotheken
# %pip install plotly
# %pip install prophet

import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql.functions import col, to_date
from pyspark.sql.types import StructType, StructField, DateType, IntegerType, StringType
from datetime import datetime
from prophet import Prophet
# Out:
# Requirement already satisfied: plotly in ./sparky-packages/lib/python3.11/site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in ./sparky-packages/lib/python3.11/site-packages (from plotly) (8.4.2)
# Requirement already satisfied: packaging in ./sparky-packages/lib/python3.11/site-packages (from plotly) (24.1)
# Requirement already satisfied: prophet in ./sparky-packages/lib/python3.11/site-packages (1.1.5)
# Requirement already satisfied: cmdstanpy>=1.0.4 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (1.2.4)
# Requirement already satisfied: numpy>=1.15.4 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (2.0.0)
# Requirement already satisfied: matplotlib>=2.0.0 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (3.9.0)
# Requirement already satisfied: pandas>=1.0.4 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays>=0.25 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (0.51)
# Requirement already satisfied: tqdm>=4.36.1 in ./sparky-packages/lib/python3.11/site-packages (from prophet) (4.66.4)
# Requirement already satisfied: importlib-resources in ./sparky-packages/lib/python3.11/site-packages (from prophet) (6.4.0)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in ./sparky-packages/lib/python3.11/site-packages (from cmdstanpy>=1.0.4->prophet) (0.5.0)
# Requirement already satisfied: python-dateutil in ./sparky-packages/lib/python3.11/site-packages (from holidays>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (24.1)
# Requirement already satisfied: pillow>=8 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./sparky-packages/lib/python3.11/site-packages (from matplotlib>=2.0.0->prophet) (3.1.2)
# Requirement already satisfied: pytz>=2020.1 in ./sparky-packages/lib/python3.11/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./sparky-packages/lib/python3.11/site-packages (from pandas>=1.0.4->prophet) (2024.1)
# Requirement already satisfied: six>=1.5 in ./sparky-packages/lib/python3.11/site-packages (from python-dateutil->holidays>=0.25->prophet) (1.16.0)

# %% [markdown]
# ## Parquet-Daten einlesen

# %%
df_customer_p = spark.read.parquet("./cleanedData/Customers.parquet", header=True, inferSchema=True)
df_customer_p.show()
df_customer_p.printSchema()
# Out:
# +--------------+------+--------+----------+
# |Customernumber|Status|Currency|Entry Date|
# +--------------+------+--------+----------+
# |    K072870000|    10|     CHF|2023-07-06|
# |    K01286ISX0|    20|     CHF|2023-07-24|
# |    K04611AAO0|    20|     CHF|2023-07-27|
# |    K04611AAR0|    20|     CHF|2023-07-27|
# |    K04611AAX0|    20|     CHF|2023-07-27|
# |    K04611AAY0|    20|     CHF|2023-07-27|
# |    K04611ABH0|    20|     CHF|2023-07-28|
# |    K11285BFG0|    20|     CHF|2023-07-31|
# |    K01795BXD0|    20|     EUR|2023-08-02|
# |    K01795BXP0|    20|     EUR|2023-08-02|
# |    K01795BXQ0|    20|     EUR|2023-08-02|
# |    K01795BYC0|    20|     EUR|2023-08-02|
# |    K01795BYJ0|    20|     EUR|2023-08-02|
# |    K01795BYM0|    20|     EUR|2023-08-02|
# |    K01795BYN0|    20|     EUR|2023-08-02|
# |    K11285BFH0|    20|     CHF|2023-08-07|
# |    K027680000|    20|     CHF|2023-08-08|
# |    K01286ITG0|    20|     CHF|2023-08-08|
# |    K04230AKI0|    20|     CHF|2023-06-02|
# |    K04230AKX0|    20|     CHF|2023-06-02|
# +--------------+------+--------+----------+
# only showing top 20 rows
#
# root
#  |-- Customernumber: string (nullable = true)
#  |-- Status: integer (nullable = true)
#  |-- Currency: string (nullable = true)
#  |-- Entry Date: date (nullable = true)
# [Stage 1:>                                                          (0 + 1) / 1]

# %% [markdown]
# ## Daten für Vorhersage vorbereiten

# %% [markdown]
# ### Dateiformat Parquet-DataFrame definieren und reduzieren

# %%
# Prüfen Format "Entry Date" für Vorhersage
df_customer_p = df_customer_p.withColumn("Entry Date", to_date(col("Entry Date"), "yyyyMMdd"))

# %%
# Trainingsaten auf das Jahr ab 2021 reduzieren (weitere Reduktionen zu späterem Zeitpunkt)
df_customer_p_reduced = df_customer_p.filter((col("Entry Date") > "2020-12-31"))

# %% [markdown]
# ### Monatlich neu aquirierte Kunden 2021

# %%
# Berechnung der täglich neu akquierten Kunden
rdd_customer = df_customer_p_reduced.rdd \
                .map(lambda x:x[3]) \
                .map(lambda x:[x, 1]) \
                .reduceByKey(lambda x,y:x+y) \
                .sortByKey()

rdd_customer.collect()
# Out:
# [(datetime.date(2021, 1, 4), 3),
#  (datetime.date(2021, 1, 5), 5),
#  (datetime.date(2021, 1, 6), 36),
#  (datetime.date(2021, 1, 7), 26),
#  (datetime.date(2021, 1, 8), 5),
#  (datetime.date(2021, 1, 11), 4),
#  (datetime.date(2021, 1, 13), 1),
#  (datetime.date(2021, 1, 14), 6),
#  (datetime.date(2021, 1, 15), 2),
#  (datetime.date(2021, 1, 18), 1),
#  (datetime.date(2021, 1, 19), 22),
#  (datetime.date(2021, 1, 20), 7),
#  (datetime.date(2021, 1, 21), 3),
#  (datetime.date(2021, 1, 25), 2),
#  (datetime.date(2021, 1, 26), 10),
#  (datetime.date(2021, 1, 27), 3),
#  (datetime.date(2021, 1, 28), 3),
#  (datetime.date(2021, 2, 1), 14),
#  (datetime.date(2021, 2, 2), 3),
#  (datetime.date(2021, 2, 3), 12),
#  (datetime.date(2021, 2, 4), 7),
#  (datetime.date(2021, 2, 5), 1),
#  (datetime.date(2021, 2, 8), 1),
#  (datetime.date(2021, 2, 9), 2),
#  (datetime.date(2021, 2, 10), 2),
#  (datetime.date(2021, 2, 11), 4),
#  (datetime.date(2021, 2, 12), 1),
#  (datetime.date(2021, 2, 16), 19),
#  (datetime.date(2021, 2, 17), 1),
#  (datetime.date(2021, 2, 18), 2),
#  (datetime.date(2021, 2, 19), 8),
#  (datetime.date(2021, 2, 22), 4),
#  (datetime.date(2021, 2, 23), 3),
#  (datetime.date(2021, 2, 24), 2),
#  (datetime.date(2021, 2, 25), 1),
#  (datetime.date(2021, 2, 26), 5),
#  (datetime.date(2021, 3, 1), 12),
#  (datetime.date(2021, 3, 2), 5),
#  (datetime.date(2021, 3, 3), 26),
#  (datetime.date(2021, 3, 4), 10),
#  (datetime.date(2021, 3, 5), 29),
#  (datetime.date(2021, 3, 8), 23),
#  (datetime.date(2021, 3, 9), 50),
#  (datetime.date(2021, 3, 10), 4),
#  (datetime.date(2021, 3, 11), 5),
#  (datetime.date(2021, 3, 12), 1),
#  (datetime.date(2021, 3, 15), 4),
#  (datetime.date(2021, 3, 16), 12),
#  (datetime.date(2021, 3, 17), 18),
#  (datetime.date(2021, 3, 19), 3),
#  (datetime.date(2021, 3, 22), 4),
#  (datetime.date(2021, 3, 23), 8),
#  (datetime.date(2021, 3, 24), 1),
#  (datetime.date(2021, 3, 25), 7),
#  (datetime.date(2021, 3, 26), 2),
#  (datetime.date(2021, 3, 29), 25),
#  (datetime.date(2021, 3, 30), 25),
#  (datetime.date(2021, 3, 31), 5),
#  (datetime.date(2021, 4, 1), 4),
#  (datetime.date(2021, 4, 6), 7),
#  (datetime.date(2021, 4, 7), 5),
#  (datetime.date(2021, 4, 8), 15),
#  (datetime.date(2021, 4, 9), 4),
#  (datetime.date(2021, 4, 12), 1),
#  (datetime.date(2021, 4, 13), 12),
#  (datetime.date(2021, 4, 14), 7),
#  (datetime.date(2021, 4, 15), 8),
#  (datetime.date(2021, 4, 16), 2),
#  (datetime.date(2021, 4, 19), 24),
#  (datetime.date(2021, 4, 20), 8),
#  (datetime.date(2021, 4, 21), 7),
#  (datetime.date(2021, 4, 22), 3),
#  (datetime.date(2021, 4, 23), 3),
#  (datetime.date(2021, 4, 26), 19),
#  (datetime.date(2021, 4, 27), 5),
#  (datetime.date(2021, 4, 28), 4),
#  (datetime.date(2021, 4, 29), 4),
#  (datetime.date(2021, 4, 30), 3),
#  (datetime.date(2021, 5, 3), 11),
#  (datetime.date(2021, 5, 4), 10),
#  (datetime.date(2021, 5, 5), 5),
#  (datetime.date(2021, 5, 6), 4),
#  (datetime.date(2021, 5, 7), 5),
#  (datetime.date(2021, 5, 10), 8),
#  (datetime.date(2021, 5, 11), 16),
#  (datetime.date(2021, 5, 12), 7),
#  (datetime.date(2021, 5, 17), 4),
#  (datetime.date(2021, 5, 18), 10),
#  (datetime.date(2021, 5, 25), 1),
#  (datetime.date(2021, 5, 26), 9),
#  (datetime.date(2021, 5, 27), 11),
#  (datetime.date(2021, 5, 28), 2),
#  (datetime.date(2021, 5, 31), 17),
#  (datetime.date(2021, 6, 1), 6),
#  (datetime.date(2021, 6, 2), 7),
#  (datetime.date(2021, 6, 3), 4),
#  (datetime.date(2021, 6, 4), 1),
#  (datetime.date(2021, 6, 7), 8),
#  (datetime.date(2021, 6, 8), 4),
#  (datetime.date(2021, 6, 9), 9),
#  (datetime.date(2021, 6, 10), 2),
#  (datetime.date(2021, 6, 11), 3),
#  (datetime.date(2021, 6, 15), 11),
#  (datetime.date(2021, 6, 16), 2),
#  (datetime.date(2021, 6, 17), 4),
#  (datetime.date(2021, 6, 18), 2),
#  (datetime.date(2021, 6, 22), 4),
#  (datetime.date(2021, 6, 23), 2),
#  (datetime.date(2021, 6, 24), 3),
#  (datetime.date(2021, 6, 25), 4),
#  (datetime.date(2021, 6, 28), 14),
#  (datetime.date(2021, 6, 29), 6),
#  (datetime.date(2021, 6, 30), 11),
#  (datetime.date(2021, 7, 1), 16),
#  (datetime.date(2021, 7, 2), 2),
#  (datetime.date(2021, 7, 4), 1),
#  (datetime.date(2021, 7, 5), 29),
#  (datetime.date(2021, 7, 6), 9),
#  (datetime.date(2021, 7, 7), 10),
#  (datetime.date(2021, 7, 8), 2),
#  (datetime.date(2021, 7, 9), 6),
#  (datetime.date(2021, 7, 12), 4),
#  (datetime.date(2021, 7, 15), 2),
#  (datetime.date(2021, 7, 16), 5),
#  (datetime.date(2021, 7, 19), 2),
#  (datetime.date(2021, 7, 20), 1),
#  (datetime.date(2021, 7, 21), 14),
#  (datetime.date(2021, 7, 22), 1),
#  (datetime.date(2021, 7, 26), 20),
#  (datetime.date(2021, 7, 27), 3),
#  (datetime.date(2021, 7, 28), 10),
#  (datetime.date(2021, 7, 29), 19),
#  (datetime.date(2021, 7, 30), 15),
#  (datetime.date(2021, 8, 2), 37),
#  (datetime.date(2021, 8, 3), 14),
#  (datetime.date(2021, 8, 4), 8),
#  (datetime.date(2021, 8, 5), 1),
#  (datetime.date(2021, 8, 6), 2),
#  (datetime.date(2021, 8, 9), 1),
#  (datetime.date(2021, 8, 11), 3),
#  (datetime.date(2021, 8, 13), 3),
#  (datetime.date(2021, 8, 16), 2),
#  (datetime.date(2021, 8, 17), 1),
#  (datetime.date(2021, 8, 18), 2),
#  (datetime.date(2021, 8, 19), 1),
#  (datetime.date(2021, 8, 20), 1),
#  (datetime.date(2021, 8, 23), 2),
#  (datetime.date(2021, 8, 24), 24),
#  (datetime.date(2021, 8, 27), 1),
#  (datetime.date(2021, 8, 30), 7),
#  (datetime.date(2021, 8, 31), 4),
#  (datetime.date(2021, 9, 1), 5),
#  (datetime.date(2021, 9, 2), 3),
#  (datetime.date(2021, 9, 3), 2),
#  (datetime.date(2021, 9, 6), 2),
#  (datetime.date(2021, 9, 7), 12),
#  (datetime.date(2021, 9, 8), 7),
#  (datetime.date(2021, 9, 9), 1),
#  (datetime.date(2021, 9, 10), 2),
#  (datetime.date(2021, 9, 13), 4),
#  (datetime.date(2021, 9, 14), 1),
#  (datetime.date(2021, 9, 15), 3),
#  (datetime.date(2021, 9, 16), 2),
#  (datetime.date(2021, 9, 17), 1),
#  (datetime.date(2021, 9, 20), 1),
#  (datetime.date(2021, 9, 21), 11),
#  (datetime.date(2021, 9, 22), 2),
#  (datetime.date(2021, 9, 23), 1),
#  (datetime.date(2021, 9, 24), 2),
#  (datetime.date(2021, 9, 27), 1),
#  (datetime.date(2021, 9, 29), 4),
#  (datetime.date(2021, 10, 1), 1),
#  (datetime.date(2021, 10, 4), 7),
#  (datetime.date(2021, 10, 6), 3),
#  (datetime.date(2021, 10, 7), 10),
#  (datetime.date(2021, 10, 8), 6),
#  (datetime.date(2021, 10, 11), 2),
#  (datetime.date(2021, 10, 12), 7),
#  (datetime.date(2021, 10, 13), 8),
#  (datetime.date(2021, 10, 14), 3),
#  (datetime.date(2021, 10, 15), 1),
#  (datetime.date(2021, 10, 19), 7),
#  (datetime.date(2021, 10, 20), 1),
#  (datetime.date(2021, 10, 21), 5),
#  (datetime.date(2021, 10, 22), 1),
#  (datetime.date(2021, 10, 25), 2),
#  (datetime.date(2021, 10, 26), 2),
#  (datetime.date(2021, 10, 27), 1),
#  (datetime.date(2021, 10, 28), 3),
#  (datetime.date(2021, 10, 29), 4),
#  (datetime.date(2021, 11, 1), 2),
#  (datetime.date(2021, 11, 2), 17),
#  (datetime.date(2021, 11, 3), 4),
#  (datetime.date(2021, 11, 4), 3),
#  (datetime.date(2021, 11, 8), 4),
#  (datetime.date(2021, 11, 9), 13),
#  (datetime.date(2021, 11, 10), 6),
#  (datetime.date(2021, 11, 11), 1),
#  (datetime.date(2021, 11, 15), 2),
#  (datetime.date(2021, 11, 17), 3),
#  (datetime.date(2021, 11, 18), 12),
#  (datetime.date(2021, 11, 22), 2),
#  (datetime.date(2021, 11, 23), 2),
#  (datetime.date(2021, 11, 24), 3),
#  (datetime.date(2021, 11, 29), 11),
#  (datetime.date(2021, 11, 30), 12),
#  (datetime.date(2021, 12, 1), 2),
#  (datetime.date(2021, 12, 2), 1),
#  (datetime.date(2021, 12, 3), 5),
#  (datetime.date(2021, 12, 6), 10),
#  (datetime.date(2021, 12, 7), 1),
#  (datetime.date(2021, 12, 8), 1),
#  (datetime.date(2021, 12, 9), 7),
#  (datetime.date(2021, 12, 10), 2),
#  (datetime.date(2021, 12, 13), 1),
#  (datetime.date(2021, 12, 14), 3),
#  (datetime.date(2021, 12, 15), 1),
#  (datetime.date(2021, 12, 16), 2),
#  (datetime.date(2021, 12, 17), 1),
#  (datetime.date(2021, 12, 20), 10),
#  (datetime.date(2022, 1, 4), 7),
#  (datetime.date(2022, 1, 5), 3),
#  (datetime.date(2022, 1, 6), 10),
#  (datetime.date(2022, 1, 7), 1),
#  (datetime.date(2022, 1, 10), 6),
#  (datetime.date(2022, 1, 11), 2),
#  (datetime.date(2022, 1, 12), 6),
#  (datetime.date(2022, 1, 13), 3),
#  (datetime.date(2022, 1, 14), 5),
#  (datetime.date(2022, 1, 17), 7),
#  (datetime.date(2022, 1, 18), 3),
#  (datetime.date(2022, 1, 19), 4),
#  (datetime.date(2022, 1, 20), 4),
#  (datetime.date(2022, 1, 21), 2),
#  (datetime.date(2022, 1, 24), 6),
#  (datetime.date(2022, 1, 25), 7),
#  (datetime.date(2022, 1, 26), 5),
#  (datetime.date(2022, 1, 28), 5),
#  (datetime.date(2022, 1, 31), 6),
#  (datetime.date(2022, 2, 1), 3),
#  (datetime.date(2022, 2, 2), 2),
#  (datetime.date(2022, 2, 3), 2),
#  (datetime.date(2022, 2, 4), 2),
#  (datetime.date(2022, 2, 7), 5),
#  (datetime.date(2022, 2, 8), 17),
#  (datetime.date(2022, 2, 9), 3),
#  (datetime.date(2022, 2, 10), 2),
#  (datetime.date(2022, 2, 11), 1),
#  (datetime.date(2022, 2, 14), 1),
#  (datetime.date(2022, 2, 15), 7),
#  (datetime.date(2022, 2, 16), 2),
#  (datetime.date(2022, 2, 17), 3),
#  (datetime.date(2022, 2, 18), 2),
#  (datetime.date(2022, 2, 21), 4),
#  (datetime.date(2022, 2, 22), 1),
#  (datetime.date(2022, 2, 24), 1),
#  (datetime.date(2022, 2, 25), 3),
#  (datetime.date(2022, 2, 28), 1),
#  (datetime.date(2022, 3, 1), 19),
#  (datetime.date(2022, 3, 2), 10),
#  (datetime.date(2022, 3, 4), 2),
#  (datetime.date(2022, 3, 7), 7),
#  (datetime.date(2022, 3, 8), 12),
#  (datetime.date(2022, 3, 9), 2),
#  (datetime.date(2022, 3, 10), 1),
#  (datetime.date(2022, 3, 11), 21),
#  (datetime.date(2022, 3, 14), 3),
#  (datetime.date(2022, 3, 15), 50),
#  (datetime.date(2022, 3, 16), 96),
#  (datetime.date(2022, 3, 17), 1),
#  (datetime.date(2022, 3, 18), 3),
#  (datetime.date(2022, 3, 21), 17),
#  (datetime.date(2022, 3, 22), 9),
#  (datetime.date(2022, 3, 23), 2),
#  (datetime.date(2022, 3, 24), 3),
#  (datetime.date(2022, 3, 25), 3),
#  (datetime.date(2022, 3, 28), 10),
#  (datetime.date(2022, 3, 29), 4),
#  (datetime.date(2022, 3, 31), 3),
#  (datetime.date(2022, 4, 1), 3),
#  (datetime.date(2022, 4, 4), 14),
#  (datetime.date(2022, 4, 5), 33),
#  (datetime.date(2022, 4, 6), 66),
#  (datetime.date(2022, 4, 7), 2),
#  (datetime.date(2022, 4, 8), 30),
#  (datetime.date(2022, 4, 11), 1),
#  (datetime.date(2022, 4, 12), 1),
#  (datetime.date(2022, 4, 13), 8),
#  (datetime.date(2022, 4, 19), 1),
#  (datetime.date(2022, 4, 20), 5),
#  (datetime.date(2022, 4, 21), 12),
#  (datetime.date(2022, 4, 22), 5),
#  (datetime.date(2022, 4, 25), 12),
#  (datetime.date(2022, 4, 26), 1),
#  (datetime.date(2022, 4, 27), 2),
#  (datetime.date(2022, 4, 28), 1),
#  (datetime.date(2022, 5, 2), 5),
#  (datetime.date(2022, 5, 3), 36),
#  (datetime.date(2022, 5, 4), 38),
#  (datetime.date(2022, 5, 5), 29),
#  (datetime.date(2022, 5, 9), 3),
#  (datetime.date(2022, 5, 10), 1),
#  (datetime.date(2022, 5, 11), 1),
#  (datetime.date(2022, 5, 12), 5),
#  (datetime.date(2022, 5, 13), 1),
#  (datetime.date(2022, 5, 16), 1),
#  (datetime.date(2022, 5, 17), 2),
#  (datetime.date(2022, 5, 18), 15),
#  (datetime.date(2022, 5, 19), 1),
#  (datetime.date(2022, 5, 20), 9),
#  (datetime.date(2022, 5, 23), 4),
#  (datetime.date(2022, 5, 24), 1),
#  (datetime.date(2022, 5, 30), 11),
#  (datetime.date(2022, 5, 31), 4),
#  (datetime.date(2022, 6, 1), 1),
#  (datetime.date(2022, 6, 2), 26),
#  (datetime.date(2022, 6, 3), 33),
#  (datetime.date(2022, 6, 7), 72),
#  (datetime.date(2022, 6, 9), 5),
#  (datetime.date(2022, 6, 10), 2),
#  (datetime.date(2022, 6, 13), 2),
#  (datetime.date(2022, 6, 14), 2),
#  (datetime.date(2022, 6, 16), 2),
#  (datetime.date(2022, 6, 17), 1),
#  (datetime.date(2022, 6, 20), 19),
#  (datetime.date(2022, 6, 21), 1),
#  (datetime.date(2023, 2, 20), 3),
#  (datetime.date(2023, 2, 21), 1),
#  (datetime.date(2023, 2, 22), 1),
#  (datetime.date(2023, 2, 23), 1),
#  (datetime.date(2023, 2, 24), 4),
#  (datetime.date(2023, 2, 27), 14),
#  (datetime.date(2023, 2, 28), 4),
#  (datetime.date(2023, 3, 1), 22),
#  (datetime.date(2023, 3, 2), 11),
#  (datetime.date(2023, 3, 3), 24),
#  (datetime.date(2023, 3, 6), 25),
#  (datetime.date(2023, 3, 7), 11),
#  (datetime.date(2023, 3, 8), 5),
#  (datetime.date(2023, 3, 9), 3),
#  (datetime.date(2023, 3, 10), 2),
#  (datetime.date(2023, 3, 14), 1),
#  (datetime.date(2023, 3, 15), 1),
#  (datetime.date(2023, 3, 16), 2),
#  (datetime.date(2023, 3, 20), 6),
#  (datetime.date(2023, 3, 21), 20),
#  (datetime.date(2023, 3, 22), 2),
#  (datetime.date(2023, 3, 23), 2),
#  (datetime.date(2023, 3, 24), 1),
#  (datetime.date(2023, 3, 27), 1),
#  (datetime.date(2023, 3, 29), 2),
#  (datetime.date(2023, 3, 30), 5),
#  (datetime.date(2023, 3, 31), 6),
#  (datetime.date(2023, 4, 3), 13),
#  (datetime.date(2023, 4, 5), 46),
#  (datetime.date(2023, 4, 6), 43),
#  (datetime.date(2023, 4, 11), 1),
#  (datetime.date(2023, 4, 12), 1),
#  (datetime.date(2023, 4, 13), 2),
#  (datetime.date(2023, 4, 14), 1),
#  (datetime.date(2023, 4, 17), 1),
#  (datetime.date(2023, 4, 18), 17),
#  (datetime.date(2023, 4, 19), 2),
#  (datetime.date(2023, 4, 25), 2),
#  (datetime.date(2023, 4, 26), 1),
#  (datetime.date(2023, 4, 27), 3),
#  (datetime.date(2023, 5, 2), 30),
#  (datetime.date(2023, 5, 3), 42),
#  (datetime.date(2023, 5, 4), 1),
#  (datetime.date(2023, 5, 5), 3),
#  (datetime.date(2023, 5, 8), 5),
#  (datetime.date(2023, 5, 9), 3),
#  (datetime.date(2023, 5, 10), 16),
#  (datetime.date(2023, 5, 11), 2),
#  (datetime.date(2023, 5, 12), 2),
#  (datetime.date(2023, 5, 15), 18),
#  (datetime.date(2023, 5, 16), 8),
#  (datetime.date(2023, 5, 17), 1),
#  (datetime.date(2023, 5, 22), 6),
#  (datetime.date(2023, 5, 23), 15),
#  (datetime.date(2023, 5, 24), 1),
#  (datetime.date(2023, 5, 25), 5),
#  (datetime.date(2023, 5, 30), 18),
#  (datetime.date(2023, 5, 31), 1),
#  (datetime.date(2023, 6, 1), 6),
#  (datetime.date(2023, 6, 2), 21),
#  (datetime.date(2023, 6, 5), 51),
#  (datetime.date(2023, 6, 6), 9),
#  (datetime.date(2023, 6, 7), 1),
#  (datetime.date(2023, 6, 8), 2),
#  (datetime.date(2023, 6, 12), 10),
#  (datetime.date(2023, 6, 13), 2),
#  (datetime.date(2023, 6, 14), 5),
#  (datetime.date(2023, 6, 16), 2),
#  (datetime.date(2023, 6, 19), 2),
#  (datetime.date(2023, 6, 20), 3),
#  (datetime.date(2023, 6, 21), 1),
#  (datetime.date(2023, 6, 22), 1),
#  (datetime.date(2023, 6, 23), 5),
#  (datetime.date(2023, 6, 26), 4),
#  (datetime.date(2023, 6, 27), 21),
#  (datetime.date(2023, 6, 28), 2),
#  (datetime.date(2023, 7, 3), 18),
#  (datetime.date(2023, 7, 4), 29),
#  (datetime.date(2023, 7, 5), 49),
#  (datetime.date(2023, 7, 6), 3),
#  (datetime.date(2023, 7, 7), 1),
#  (datetime.date(2023, 7, 11), 1),
#  (datetime.date(2023, 7, 13), 4),
#  (datetime.date(2023, 7, 14), 20),
#  (datetime.date(2023, 7, 17), 2),
#  (datetime.date(2023, 7, 18), 2),
#  (datetime.date(2023, 7, 19), 4),
#  (datetime.date(2023, 7, 20), 1),
#  (datetime.date(2023, 7, 21), 1),
#  (datetime.date(2023, 7, 24), 20),
#  (datetime.date(2023, 7, 25), 1),
#  (datetime.date(2023, 7, 26), 10),
#  (datetime.date(2023, 7, 27), 18),
#  (datetime.date(2023, 7, 28), 11),
#  (datetime.date(2023, 7, 31), 4),
#  (datetime.date(2023, 8, 2), 37),
#  (datetime.date(2023, 8, 3), 2),
#  (datetime.date(2023, 8, 4), 1),
#  (datetime.date(2023, 8, 7), 1),
#  (datetime.date(2023, 8, 8), 10),
#  (datetime.date(2023, 8, 9), 7),
#  (datetime.date(2023, 8, 10), 1),
#  (datetime.date(2023, 8, 14), 4),
#  (datetime.date(2023, 8, 15), 2),
#  (datetime.date(2023, 8, 16), 2),
#  (datetime.date(2023, 8, 18), 2),
#  (datetime.date(2023, 8, 21), 1),
#  (datetime.date(2023, 8, 22), 2),
#  (datetime.date(2023, 8, 23), 1),
#  (datetime.date(2023, 8, 24), 1),
#  (datetime.date(2023, 8, 25), 2),
#  (datetime.date(2023, 8, 28), 30),
#  (datetime.date(2023, 8, 29), 17),
#  (datetime.date(2023, 8, 30), 1),
#  (datetime.date(2023, 8, 31), 2),
#  (datetime.date(2023, 9, 1), 23),
#  (datetime.date(2023, 9, 4), 35),
#  (datetime.date(2023, 9, 5), 26),
#  (datetime.date(2023, 9, 6), 11),
#  (datetime.date(2023, 9, 7), 14),
#  (datetime.date(2023, 9, 8), 10),
#  (datetime.date(2023, 9, 12), 2),
#  (datetime.date(2023, 9, 14), 3),
#  (datetime.date(2023, 9, 15), 1),
#  (datetime.date(2023, 9, 18), 15),
#  (datetime.date(2023, 9, 19), 1),
#  (datetime.date(2023, 9, 20), 3),
#  (datetime.date(2023, 9, 21), 1),
#  (datetime.date(2023, 9, 22), 2),
#  (datetime.date(2023, 9, 25), 13),
#  (datetime.date(2023, 9, 26), 2),
#  (datetime.date(2023, 9, 27), 1),
#  (datetime.date(2023, 9, 28), 1),
#  (datetime.date(2023, 9, 29), 1),
#  (datetime.date(2023, 10, 2), 50),
#  (datetime.date(2023, 10, 3), 16),
#  (datetime.date(2023, 10, 4), 40),
#  (datetime.date(2023, 10, 5), 12),
#  (datetime.date(2023, 10, 10), 1),
#  (datetime.date(2023, 10, 12), 4),
#  (datetime.date(2023, 10, 16), 16),
#  (datetime.date(2023, 10, 17), 9),
#  (datetime.date(2024, 6, 17), 20),
#  (datetime.date(2024, 6, 18), 1),
#  (datetime.date(2024, 6, 19), 8),
#  (datetime.date(2024, 6, 20), 14),
#  (datetime.date(2024, 6, 21), 23)]

# %%
# RDD nur auf Monatbasis mappen
rdd_customer_month = rdd_customer.map(lambda x: ((x[0].year, x[0].month), x[1]))

# Die Anzahl von Neukunden pro Monat des jeweiligen Jahres aufaddieren
rdd_aggregated = rdd_customer_month.reduceByKey(lambda a, b: a + b).sortByKey()

rdd_aggregated.collect()
# Out:
# [((2021, 1), 139),
#  ((2021, 2), 92),
#  ((2021, 3), 279),
#  ((2021, 4), 145),
#  ((2021, 5), 120),
#  ((2021, 6), 107),
#  ((2021, 7), 171),
#  ((2021, 8), 114),
#  ((2021, 9), 67),
#  ((2021, 10), 74),
#  ((2021, 11), 97),
#  ((2021, 12), 47),
#  ((2022, 1), 92),
#  ((2022, 2), 62),
#  ((2022, 3), 278),
#  ((2022, 4), 197),
#  ((2022, 5), 167),
#  ((2022, 6), 227),
#  ((2022, 7), 94),
#  ((2022, 8), 237),
#  ((2022, 9), 189),
#  ((2022, 10), 156),
#  ((2022, 11), 192),
#  ((2022, 12), 186),
#  ((2023, 1), 155),
#  ((2023, 2), 160),
#  ((2023, 3), 152),
#  ((2023, 4), 133),
#  ((2023, 5), 177),
#  ((2023, 6), 148),
#  ((2023, 7), 199),
#  ((2023, 8), 126),
#  ((2023, 9), 165),
#  ((2023, 10), 230),
#  ((2023, 11), 53),
#  ((2023, 12), 256),
#  ((2024, 1), 147),
#  ((2024, 2), 191),
#  ((2024, 3), 204),
#  ((2024, 4), 189),
#  ((2024, 5), 158),
#  ((2024, 6), 161)]

# %%
# Datum RDD konvertieren
# a) tuple => string
rdd_string = rdd_aggregated.map(lambda x: (f"{x[0][0]}{x[0][1]:02d}", x[1]))
# b) string => DateTime
rdd_date_time = rdd_string.map(lambda x: (datetime.strptime(x[0], "%Y%m"), int(x[1])))

rdd_date_time.collect()
# Out:
# [(datetime.datetime(2021, 1, 1, 0, 0), 139),
#  (datetime.datetime(2021, 2, 1, 0, 0), 92),
#  (datetime.datetime(2021, 3, 1, 0, 0), 279),
#  (datetime.datetime(2021, 4, 1, 0, 0), 145),
#  (datetime.datetime(2021, 5, 1, 0, 0), 120),
#  (datetime.datetime(2021, 6, 1, 0, 0), 107),
#  (datetime.datetime(2021, 7, 1, 0, 0), 171),
#  (datetime.datetime(2021, 8, 1, 0, 0), 114),
#  (datetime.datetime(2021, 9, 1, 0, 0), 67),
#  (datetime.datetime(2021, 10, 1, 0, 0), 74),
#  (datetime.datetime(2021, 11, 1, 0, 0), 97),
#  (datetime.datetime(2021, 12, 1, 0, 0), 47),
#  (datetime.datetime(2022, 1, 1, 0, 0), 92),
#  (datetime.datetime(2022, 2, 1, 0, 0), 62),
#  (datetime.datetime(2022, 3, 1, 0, 0), 278),
#  (datetime.datetime(2022, 4, 1, 0, 0), 197),
#  (datetime.datetime(2022, 5, 1, 0, 0), 167),
#  (datetime.datetime(2022, 6, 1, 0, 0), 227),
#  (datetime.datetime(2022, 7, 1, 0, 0), 94),
#  (datetime.datetime(2022, 8, 1, 0, 0), 237),
#  (datetime.datetime(2022, 9, 1, 0, 0), 189),
#  (datetime.datetime(2022, 10, 1, 0, 0), 156),
#  (datetime.datetime(2022, 11, 1, 0, 0), 192),
#  (datetime.datetime(2022, 12, 1, 0, 0), 186),
#  (datetime.datetime(2023, 1, 1, 0, 0), 155),
#  (datetime.datetime(2023, 2, 1, 0, 0), 160),
#  (datetime.datetime(2023, 3, 1, 0, 0), 152),
#  (datetime.datetime(2023, 4, 1, 0, 0), 133),
#  (datetime.datetime(2023, 5, 1, 0, 0), 177),
#  (datetime.datetime(2023, 6, 1, 0, 0), 148),
#  (datetime.datetime(2023, 7, 1, 0, 0), 199),
#  (datetime.datetime(2023, 8, 1, 0, 0), 126),
#  (datetime.datetime(2023, 9, 1, 0, 0), 165),
#  (datetime.datetime(2023, 10, 1, 0, 0), 230),
#  (datetime.datetime(2023, 11, 1, 0, 0), 53),
#  (datetime.datetime(2023, 12, 1, 0, 0), 256),
#  (datetime.datetime(2024, 1, 1, 0, 0), 147),
#  (datetime.datetime(2024, 2, 1, 0, 0), 191),
#  (datetime.datetime(2024, 3, 1, 0, 0), 204),
#  (datetime.datetime(2024, 4, 1, 0, 0), 189),
#  (datetime.datetime(2024, 5, 1, 0, 0), 158),
#  (datetime.datetime(2024, 6, 1, 0, 0), 161)]

# %% [markdown]
# ### RDD für Prophet-Analyse in Spark DataFrame umwandeln

# %%
# Schema definieren
schema = StructType([
    StructField("ds", DateType()),
    StructField("y", IntegerType())
])

# RDD in PySpark DataFrame konvertieren
df_new_customer = spark.createDataFrame(rdd_date_time, schema)

# Datum string in DateTime konvertieren (yyyyMM)
#df_new_customer = df_new_customer.withColumn('ds', to_date(col('ds'), "yyyyMM"))

df_new_customer.show()
df_new_customer.printSchema()

df_new_customer_pd = df_new_customer.toPandas()
df_new_customer_pd['ds'] = pd.to_datetime(df_new_customer_pd['ds'])

df_new_customer_pd.head(20)
# Out:
# +----------+---+
# |        ds|  y|
# +----------+---+
# |2021-01-01|139|
# |2021-02-01| 92|
# |2021-03-01|279|
# |2021-04-01|145|
# |2021-05-01|120|
# |2021-06-01|107|
# |2021-07-01|171|
# |2021-08-01|114|
# |2021-09-01| 67|
# |2021-10-01| 74|
# |2021-11-01| 97|
# |2021-12-01| 47|
# |2022-01-01| 92|
# |2022-02-01| 62|
# |2022-03-01|278|
# |2022-04-01|197|
# |2022-05-01|167|
# |2022-06-01|227|
# |2022-07-01| 94|
# |2022-08-01|237|
# +----------+---+
# only showing top 20 rows
#
# root
#  |-- ds: date (nullable = true)
#  |-- y: integer (nullable = true)
#            ds    y
# 0  2021-01-01  139
# 1  2021-02-01   92
# 2  2021-03-01  279
# 3  2021-04-01  145
# 4  2021-05-01  120
# 5  2021-06-01  107
# 6  2021-07-01  171
# 7  2021-08-01  114
# 8  2021-09-01   67
# 9  2021-10-01   74
# 10 2021-11-01   97
# 11 2021-12-01   47
# 12 2022-01-01   92
# 13 2022-02-01   62
# 14 2022-03-01  278
# 15 2022-04-01  197
# 16 2022-05-01  167
# 17 2022-06-01  227
# 18 2022-07-01   94
# 19 2022-08-01  237

# %% [markdown]
# ## Explanation and Execution of Prophet Forecasts
#
# **ds (Date Series):**
#
# This column contains the timestamps for the forecasted values. It corresponds to the future dates for which the forecast has been generated.
#
# **yhat (Forecasted Value):**
#
# This column contains the forecasted values of the time series. It is the primary output of the Prophet model and represents the predicted values for the corresponding dates in the ds column.
#
# **yhat_lower (Lower Bound of Forecast):**
#
# This column contains the lower bound of the forecasted values' uncertainty interval. It provides a conservative estimate of the forecast, giving an idea of the potential minimum value the forecast might take.
#
# **yhat_upper (Upper Bound of Forecast):**
#
# This column contains the upper bound of the forecasted values' uncertainty interval. It provides a liberal estimate of the forecast, giving an idea of the potential maximum value the forecast might take.

# %% [markdown]
# ### Zeitspanne DataFrames definieren

# %%
# Daten in Forecast-Set und Test-Set splitten
date_begin_forecast = datetime(2022, 1, 1)
date_end_forecast = datetime(2022, 7, 1)

# DataFrame für Vorhersage (2021)
df_modell_forecast = df_new_customer_pd[df_new_customer_pd['ds'] < date_begin_forecast]

# DataFrame mit Echtdaten für Vergleich mit Vorhersage (2022-01-01 bis 2022-06-30)
df_modell_test = df_new_customer_pd[(df_new_customer_pd['ds'] >= date_begin_forecast) & (df_new_customer_pd['ds'] < date_end_forecast)]

print("Forecast Set:")
print(df_modell_forecast.head(20))
print("\nTest Set:")
print(df_modell_test.head(20))
# Out:
# Forecast Set:
#            ds    y
# 0  2021-01-01  139
# 1  2021-02-01   92
# 2  2021-03-01  279
# 3  2021-04-01  145
# 4  2021-05-01  120
# 5  2021-06-01  107
# 6  2021-07-01  171
# 7  2021-08-01  114
# 8  2021-09-01   67
# 9  2021-10-01   74
# 10 2021-11-01   97
# 11 2021-12-01   47
#
# Test Set:
#            ds    y
# 12 2022-01-01   92
# 13 2022-02-01   62
# 14 2022-03-01  278
# 15 2022-04-01  197
# 16 2022-05-01  167
# 17 2022-06-01  227

# %% [markdown]
# ### Prophet Modelle initialisieren

# %%
# Modell initialisieren
model = Prophet(interval_width=0.95, daily_seasonality=False)

# Modell mit Daten 2021 trainieren
model.fit(df_modell_forecast)

# DataFrame erstellen, das Vorhersagedaten enthält (6 Monate, ab 01.01.2022 - 30.06.2022)
future = model.make_future_dataframe(periods=6, freq='M')  

# Vorhersage generieren
forecast = model.predict(future)

# Ausgabe Trainings- und Vorhersagedaten
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].head(20)
# Out:
# 06:25:19 - cmdstanpy - INFO - Chain [1] start processing
# 06:25:19 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 0  2021-01-01  173.760921   84.053477  260.549242
# 1  2021-02-01  163.939023   71.236508  257.522392
# 2  2021-03-01  155.067632   61.700737  244.493544
# 3  2021-04-01  145.245734   49.598898  233.725644
# 4  2021-05-01  135.740672   41.439839  229.061023
# 5  2021-06-01  125.918774   32.775739  224.585428
# 6  2021-07-01  116.413712   21.188348  208.322462
# 7  2021-08-01  106.591815   16.336602  200.435608
# 8  2021-09-01   96.769917    2.970735  192.098352
# 9  2021-10-01   87.264855   -7.770823  180.960842
# 10 2021-11-01   77.442957  -14.444323  175.214239
# 11 2021-12-01   67.937895  -19.669563  153.837913
# 12 2021-12-31   58.432833  -38.782618  152.148152
# 13 2022-01-31   48.610935  -42.582980  140.765776
# 14 2022-02-28   39.739544  -52.856095  134.823882
# 15 2022-03-31   29.917646  -67.292836  123.243619
# 16 2022-04-30   20.412584  -70.444969  113.759486
# 17 2022-05-31   10.590686  -82.320146  103.429351

# %%
# Prophet Modell mit 0 Monaten Prognose für gleiches Plotting der Vergleichsdaten (01.01.2022-30.06.2022)
model = Prophet(interval_width=0.95, daily_seasonality=True)
model.fit(df_modell_forecast)
future = model.make_future_dataframe(periods=0, freq='M') 
forecast_test = model.predict(future)

forecast_test[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(6)
# Out:
# 06:25:21 - cmdstanpy - INFO - Chain [1] start processing
# 06:25:21 - cmdstanpy - INFO - Chain [1] done processing
#            ds        yhat  yhat_lower  yhat_upper
# 6  2021-07-01  116.314899   23.732531  210.244882
# 7  2021-08-01  106.446131   12.727715  201.880374
# 8  2021-09-01   96.577363    5.085961  191.967160
# 9  2021-10-01   87.026943   -1.798833  182.783675
# 10 2021-11-01   77.158175   -6.638338  173.766865
# 11 2021-12-01   67.607754  -27.423230  162.767213

# %% [markdown]
# ## Plotting Vorhersage und Vergleich mit Echtdaten

# %%
# Plotanzeige in Zetiraum Echtdaten und Vorhersage-Daten splitten
date_split = pd.to_datetime('2021-12')
forecast_before = forecast[forecast['ds'] <= date_split]
forecast_after = forecast[forecast['ds'] >= date_split]

fig, ax = plt.subplots(figsize=(10, 6))

# Achsen definieren
ax.set_xlabel('Jahr-Monat')
#ax.set_xticks(df_new_customer_pd['ds'][::1])  # Setzt die Ticks auf der x-Achse jeden Monat
ax.set_ylabel('Neue Kunden')
ax.set_title('Prognose/Abgleich monatliche neue Kunden 01/2022 - 06/2022')

# Grid aktivieren
ax.grid(True, zorder=0)

# Linien plotten mit definierten Farben
line1, = ax.plot(forecast_before['ds'], forecast_before['yhat'], 
                 label='Data trend', color="lightblue", linewidth=3)
line2, = ax.plot(forecast_after['ds'], forecast_after['yhat'], 
                 label='Forecast trend', color="orange", linewidth=3)

# Konfidenzintervalle für Echtdaten und Vorhersagedaten definieren
ax.fill_between(forecast_after['ds'], forecast_after['yhat_lower'], forecast_after['yhat_upper'], 
                color='orange', alpha=0.5, label='Uncertainity interval forecast')

# Effektive Daten anzeigen
ax.scatter(df_modell_forecast['ds'], df_modell_forecast['y'], label='Data points', zorder=2)
ax.scatter(df_modell_test['ds'], df_modell_test['y'], 
           color="black", label='Real data points (comparison)', zorder=2)

# Add the legend back with the desired entries
ax.legend(loc='lower left', title='Legend', fontsize='small', shadow=True, frameon=True)

# Show the plot
plt.show()

# %%
sc.stop()

# %% [markdown]
# Sources:
# - https://medium.com/analytics-vidhya/time-series-forecasting-arima-vs-prophet-5015928e402a
# - https://www.kaggle.com/code/kakkarot/starter-hourly-energy-consumption-b71f2600-a
# - https://www.youtube.com/watch?v=KvLG1uTC-KU
